# %%
# !pip install opencv-python
# !pip install rawpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 164.0 MB/s eta 0:00:0000:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Import packages
import os
import matplotlib.pyplot as plt
import numpy as np

# Good practice to import non-standard packages after standard
import image as pvim

# %%
# Get files
# select folder with files of interest. Example below
el_dir = "occc"
el_files = os.listdir(el_dir)
# Printout for sanity check. You can comment it out
#print(el_files)
# Out:
# []

# %%
# Read data from files
# For the sake of this demo, I am only reading one file and going through each function individually. The functions in this mini-pipeline are combined in one function in SintonFMT_LIB
# Set values: rsh_v_cell does not change; if sun is set to a value, the analysis only returns results for that one intensity
el_file = f"{el_dir}/{el_files[0]}"

image_raw = pvim.choose_image_reader(image_filepath = el_raw_file, for_analysis=True, image_32F=False)
image_proc = pvim.choose_image_reader(image_filepath = el_raw_file, for_analysis=False, image_32F=False)

# %%
# Run this block and observe the values. Why do they differ?
print(f"Average pixel value for raw image = {np.mean(image_raw)}")
print(f"Average pixel value for processed image = {np.mean(image_proc[:,:,2])}")
print(f"Max pixel value for raw image = {np.max(image_raw)}")
print(f"Max pixel value for processed image = {np.max(image_proc[:,:,2])}")
# Out:
# Average pixel value for raw image = 99.2427797280527
# Average pixel value for processed image = 40.227243269022225
# Max pixel value for raw image = 983
# Max pixel value for processed image = 217

# %%
# Out:
# array([[ 0,  0,  0],
#        [ 5,  0,  0],
#        [10,  0,  2],
#        ...,
#        [ 0,  1,  0],
#        [ 0,  0,  2],
#        [ 0,  0,  6]], dtype=uint8)

# %%
# Check out the EL images! Why do you think they look so different?
plt.imshow(image_raw,cmap='gray')
plt.title('Raw')
plt.show()

image_proc_gc = pvim.convert_to_grayscale(image_proc)
plt.imshow(image_proc_gc,cmap='gray')
plt.title('Processed')
plt.show()
